# %%
import numpy as np

# %%
np.array([2,3,4,5,6])
# Out:
# array([2, 3, 4, 5, 6])

# %%
type(np.array([2,3,4,5,6]))
# Out:
# numpy.ndarray

# %%
np.array([[2,3,4],[5,6,7]])
# Out:
# array([[2, 3, 4],
#        [5, 6, 7]])

# %%
l=[[1,2,3,4],[5,6,7,8]]
l[0][0]
# Out:
# 1

# %%
a=np.array([1,2,3,4],ndmin=3)

# %%
a
# Out:
# array([[[1, 2, 3, 4]]])

# %%
arr=np.array([[1,2,3],[4,5,6],[6,7,8]])
arr
# Out:
# array([[1, 2, 3],
#        [4, 5, 6],
#        [6, 7, 8]])

# %%
arr.ndim
# Out:
# 2

# %%
np.random.randint(1,10,(4,4))
# Out:
# array([[8, 9, 1, 8],
#        [2, 9, 5, 8],
#        [5, 6, 5, 5],
#        [9, 3, 3, 4]])

# %%
np.random.randint(1,10,(4,4,2))
# Out:
# array([[[3, 9],
#         [4, 6],
#         [3, 3],
#         [8, 7]],
#
#        [[7, 8],
#         [1, 5],
#         [6, 7],
#         [1, 8]],
#
#        [[8, 6],
#         [9, 5],
#         [4, 2],
#         [6, 6]],
#
#        [[6, 4],
#         [4, 5],
#         [9, 2],
#         [5, 2]]])

# %%
np.random.randint(1,10,(2,3,3))
# Out:
# array([[[1, 1, 3],
#         [9, 4, 6],
#         [7, 8, 5]],
#
#        [[1, 9, 1],
#         [1, 6, 8],
#         [9, 2, 2]]])

# %%
l=[1,2,3,4,5,6,5,4,3]

# %%
np.array(l)
# Out:
# array([1, 2, 3, 4, 5, 6, 5, 4, 3])

# %%
l1=[4,5,6,7,'sudh',3.45,True]

# %%
np.array(l1)
#it will convert all in string
# it will convert all element in higher element value
# Out:
# array(['4', '5', '6', '7', 'sudh', '3.45', 'True'], dtype='<U32')

# %%
# Out:
# 2
