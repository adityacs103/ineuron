# %%
import pandas as pd

# %%
'''Task
AgentLoginReport and AgentPerformance
weekly rating report
1. find out there average rating on weekly basis keep it in the mind they work five day in a week
2. total working days for each agent
3. total query that you have taken
4. total feedback that you have recieved
5. a agent name who have average raring between 3.5 to 4
6. Agent name who have rating less than 3.5
7. Agent name who have rating more than 4.5
8. how many feedback agent have more than 4.5 average
9. average weekly response time for each agents 
10. average weekly resolution time for each agents 
11.  list of all agents name
12. percentage of chat on wich they have recieved a feedback
13. total contribution hour for each and every agent weekly basis 
14. total percentage of active hour for a month 
'''
# Out:
# 'Task\nAgentLoginReport and AgentPerformance\nweekly rating report\n1. find out there average rating on weekly basis keep it in the mind they work five day in a week\n2. total working days for each agent\n3. total query that you have taken\n4. total feedback that you have recieved\n5. a agent name who have average raring between 3.5 to 4\n6. Agent name who have rating less than 3.5\n7. Agent name who have rating more than 4.5\n8. how many feedback agent have more than 4.5 average\n9. average weekly response time for each agents \n10. average weekly resolution time for each agents \n11.  list of all agents name\n12. percentage of chat on wich they have recieved a feedback\n13. total contribution hour for each and every agent weekly basis \n14. total percentage of active hour for a month \n'

# %%
df=pd.read_csv('https://raw.githubusercontent.com/adityacs103/ineuron/main/pandas/AgentPerformance.csv')
df
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1  7/30/2022        Prerna Singh           11               0:00:38
# 1         2  7/30/2022       Nandani Gupta           11               0:01:15
# 2         3  7/30/2022          Ameya Jain           14               0:00:30
# 3         4  7/30/2022       Mahesh Sarade           14               0:01:04
# 4         5  7/30/2022              Swati            14               0:01:11
# ...     ...        ...                 ...          ...                   ...
# 2155   2156   7/1/2022   Sowmiya Sivakumar            0               0:00:00
# 2156   2157   7/1/2022             Nitin M            0               0:00:00
# 2157   2158   7/1/2022              Vivek             0               0:00:00
# 2158   2159   7/1/2022       Ayushi Mishra            0               0:00:00
# 2159   2160   7/1/2022  Chaitra K Hiremath            0               0:00:00
#
# ...

# %%
df= df[df['Total Chats'] != 0]
df
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1  7/30/2022        Prerna Singh           11               0:00:38
# 1         2  7/30/2022       Nandani Gupta           11               0:01:15
# 2         3  7/30/2022          Ameya Jain           14               0:00:30
# 3         4  7/30/2022       Mahesh Sarade           14               0:01:04
# 4         5  7/30/2022              Swati            14               0:01:11
# ...     ...        ...                 ...          ...                   ...
# 2101   2102   7/1/2022       Jaydeep Dixit           25               0:01:15
# 2102   2103   7/1/2022  Shivananda Sonwane           23               0:01:24
# 2103   2104   7/1/2022      Khushboo Priya           24               0:01:46
# 2104   2105   7/1/2022     Hrisikesh Neogi           15               0:01:05
# 2105   2106   7/1/2022              Tarun            22               0:00:00
#
# ...

# %%
df.groupby('Agent Name')['Average Rating'].mean()
# Out:
# Agent Name
# Aditya Shinde             4.500833
# Aditya_iot                4.138824
# Ameya Jain                4.439333
# Anirudh                   2.764286
# Ankitjha                  2.666667
# Anurag Tiwari             2.750000
# Aravind                   4.674286
# Ashad Nasim               2.500000
# Ayushi Mishra             4.352500
# Bharath                   4.711053
# Boktiar Ahmed Bappy       4.116923
# Chaitra K Hiremath        4.323333
# Deepranjan Gupta          4.123810
# Dibyanshu                 0.000000
# Harikrishnan Shaji        4.167895
# Hitesh Choudhary          0.000000
# Hrisikesh Neogi           4.480476
# Ishawant Kumar            4.429167
# Jawala Prakash            4.166400
# Jayant Kumar              4.007500
# Jaydeep Dixit             4.524286
# Khushboo Priya            4.273462
# Madhulika G               4.373333
# Mahak                     3.000000
# Mahesh Sarade             4.000556
# Maitry                    4.390500
# ...

# %%
df[df['Agent Name']=='Hitesh Choudhary']
# Out:
#       SL No       Date        Agent Name  Total Chats Average Response Time  \
# 1146   1147  7/15/2022  Hitesh Choudhary            1               0:00:00
#
#      Average Resolution Time  Average Rating  Total Feedback
# 1146                 0:01:25             0.0               0

# %%
df.groupby('Agent Name').count()
# Out:
#                         SL No  Date  Total Chats  Average Response Time  \
# Agent Name
# Aditya Shinde              12    12           12                     12
# Aditya_iot                 17    17           17                     17
# Ameya Jain                 15    15           15                     15
# Anirudh                     7     7            7                      7
# Ankitjha                    3     3            3                      3
# Anurag Tiwari               2     2            2                      2
# Aravind                    14    14           14                     14
# Ashad Nasim                 2     2            2                      2
# Ayushi Mishra              24    24           24                     24
# Bharath                    19    19           19                     19
# Boktiar Ahmed Bappy        26    26           26                     26
# Chaitra K Hiremath          6     6            6                      6
# ...
